# %% [markdown]
# <a href="https://colab.research.google.com/github/renisha04/Machine-Learning-Lab/blob/main/ML_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data = pd.read_csv("Mall_Customers.csv")

print("Dataset loaded successfully!")
print(data.head())
# Out:
# Dataset loaded successfully!
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
X = data[['Annual Income (k$)', 'Spending Score (1-100)']]

# %%
k = 5

# %%
kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)

# %%
data['Cluster'] = kmeans.fit_predict(X)

print("\nCluster labels assigned successfully!")

print("\nCustomer Segmentation:")
print(data[['CustomerID', 'Annual Income (k$)',
            'Spending Score (1-100)', 'Cluster']].head(20))

print("\nCluster Centers:")
print(kmeans.cluster_centers_)
# Out:
# Cluster labels assigned successfully!
#
# Customer Segmentation:
#     CustomerID  Annual Income (k$)  Spending Score (1-100)  Cluster
# 0            1                  15                      39        4
# 1            2                  15                      81        2
# 2            3                  16                       6        4
# 3            4                  16                      77        2
# 4            5                  17                      40        4
# 5            6                  17                      76        2
# 6            7                  18                       6        4
# 7            8                  18                      94        2
# 8            9                  19                       3        4
# 9           10                  19                      72        2
# 10          11                  19                      14        4
# 11          12                  19                      99        2
# ...

# %%
plt.figure(figsize=(8, 6))

plt.scatter(
    X['Annual Income (k$)'],
    X['Spending Score (1-100)'],
    c=data['Cluster'],
    cmap='viridis',
    s=60
)

plt.scatter(
    kmeans.cluster_centers_[:, 0],
    kmeans.cluster_centers_[:, 1],
    s=200,
    c='red',
    marker='X',
    label='Cluster Centers'
)

plt.title("Customer Segmentation Using K-Means")
plt.xlabel("Annual Income (k$)")
plt.ylabel("Spending Score (1-100)")
plt.legend()
plt.grid(True)
plt.show()

print("\nCustomer segmentation completed successfully!")
# Out:
# Customer segmentation completed successfully!
